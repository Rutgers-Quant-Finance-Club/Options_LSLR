# %% [markdown]
# # LSM Paper Math Walkthrough (Weeks 1-4)
#
# This notebook summarizes the Sections 1-3 logic used by the implementation.
# See `docs/week1_math_breakdown.md` for the full memo.

# %% [markdown]
# ## Key objects
# - Intrinsic value for put: $(K-S_t)^+$
# - Continuation value: conditional expectation under $Q$
# - Regression target: discounted realized future continuation cash flow
# - Basis: constant + first three weighted Laguerre terms
